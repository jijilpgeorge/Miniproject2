# %%
'''Write a python program to replicate a Banking system. The following features are mandatory:
1. Account login
2. Amount Depositing
3. Amount Withdrawal
Other than the above features you can add any other also.'''

# %%
class BankAccount:
    def __init__(self, account_number, pin, balance=0):
        self.account_number = account_number
        self.pin = pin
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print("Deposit successful. Your new balance is:", self.balance)
        else:
            print("Invalid amount for deposit.")

    def withdraw(self, amount):
        if amount > 0:
            if self.balance >= amount:
                self.balance -= amount
                print("Withdrawal successful. Your new balance is:", self.balance)
            else:
                print("Insufficient balance.")
        else:
            print("Invalid amount for withdrawal.")

    def check_balance(self):
        print("Your current balance is:", self.balance)

def main():
    # Create bank account
    account_number = input("Enter your account number: ")
    pin = input("Enter your PIN: ")
    bank_account = BankAccount(account_number, pin)

    # Login
    attempts = 0
    while attempts < 3:
        entered_pin = input("Enter your PIN to login: ")
        if entered_pin == bank_account.pin:
            print("Login successful.")
            break
        else:
            attempts += 1
            print("Invalid PIN. Please try again.")

    if attempts == 3:
        print("Too many failed login attempts. Exiting.")
        return

    # Menu
    while True:
        print("\nMenu:")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Exit")

        choice = input("Enter your choice: ")

        if choice == '1':
            amount = float(input("Enter amount to deposit: "))
            bank_account.deposit(amount)
        elif choice == '2':
            amount = float(input("Enter amount to withdraw: "))
            bank_account.withdraw(amount)
        elif choice == '3':
            bank_account.check_balance()
        elif choice == '4':
            print("Thank you for banking with us. Goodbye!")
            break
        else:
            print("Invalid choice. Please enter a valid option.")

if __name__ == "__main__":
    main()
# Out:
# Enter your account number: 8547964
# Enter your PIN: 5874
# Enter your PIN to login: 54
# Invalid PIN. Please try again.
# Enter your PIN to login: 5874
# Login successful.
#
# Menu:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice: 4
# Thank you for banking with us. Goodbye!

# %%
class BankAccount:
    def __init__(self, name, balance=0):
        self.name = name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount} into {self.name}'s account.")
            self.show_balance()
        else:
            print("Invalid deposit amount.")

    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew {amount} from {self.name}'s account.")
            self.show_balance()
        else:
            print("Insufficient funds or invalid withdrawal amount.")

    def show_balance(self):
        print(f"{self.name}'s account balance: {self.balance}")

# Sample usage
def main():
    print("Welcome to the Python Bank!")
    name = input("Enter your name: ")
    account = BankAccount(name)

    while True:
        print("\nOptions:")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Exit")

        choice = input("Enter your choice (1/2/3/4): ")

        if choice == '1':
            amount = float(input("Enter amount to deposit: "))
            account.deposit(amount)
        elif choice == '2':
            amount = float(input("Enter amount to withdraw: "))
            account.withdraw(amount)
        elif choice == '3':
            account.show_balance()
        elif choice == '4':
            print("Thank you for using Python Bank. Have a great day!")
            break
        else:
            print("Invalid choice. Please choose again.")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Python Bank!
# Enter your name: Jijil
#
# Options:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1/2/3/4): 3
# Jijil's account balance: 0
#
# Options:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1/2/3/4): 1
# Enter amount to deposit: 587454
# Deposited 587454.0 into Jijil's account.
# Jijil's account balance: 587454.0
#
# Options:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1/2/3/4): 1
# Enter amount to deposit: 5241
# Deposited 5241.0 into Jijil's account.
# Jijil's account balance: 592695.0
#
# Options:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1/2/3/4): 3
# Jijil's account balance: 592695.0
#
# Options:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1/2/3/4): 2
# Enter amount to withdraw: 10000
# Withdrew 10000.0 from Jijil's account.
# Jijil's account balance: 582695.0
#
# Options:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1/2/3/4): 4
# Thank you for using Python Bank. Have a great day!

# %%
class BankAccount:
    def __init__(self, name, balance=0):
        self.name = name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount} into {self.name}'s account.")
            self.show_balance()
        else:
            print("Invalid deposit amount.")

    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew {amount} from {self.name}'s account.")
            self.show_balance()
        else:
            print("Insufficient funds or invalid withdrawal amount.")

    def show_balance(self):
        print(f"{self.name}'s account balance: {self.balance}")


class Bank:
    def __init__(self):
        self.accounts = {}

    def create_account(self, name):
        if name in self.accounts:
            print("Account already exists.")
        else:
            self.accounts[name] = BankAccount(name)
            print("Account created successfully.")

    def login(self, name):
        if name in self.accounts:
            print(f"Welcome back, {name}!")
            return self.accounts[name]
        else:
            print("Account not found. Please create an account.")
            return None


def main():
    print("Welcome to the Python Bank!")
    bank = Bank()

    while True:
        print("\nOptions:")
        print("1. Create Account")
        print("2. Login")
        print("3. Exit")

        choice = input("Enter your choice (1/2/3): ")

        if choice == '1':
            name = input("Enter your name: ")
            bank.create_account(name)
        elif choice == '2':
            name = input("Enter your name: ")
            account = bank.login(name)
            if account:
                account_menu(account)
        elif choice == '3':
            print("Thank you for using Python Bank. Have a great day!")
            break
        else:
            print("Invalid choice. Please choose again.")


def account_menu(account):
    while True:
        print("\nAccount Options:")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Logout")

        choice = input("Enter your choice (1/2/3/4): ")

        if choice == '1':
            amount = float(input("Enter amount to deposit: "))
            account.deposit(amount)
        elif choice == '2':
            amount = float(input("Enter amount to withdraw: "))
            account.withdraw(amount)
        elif choice == '3':
            account.show_balance()
        elif choice == '4':
            print("Logged out successfully.")
            break
        else:
            print("Invalid choice. Please choose again.")


if __name__ == "__main__":
    main()
# Out:
# Welcome to the Python Bank!
#
# Options:
# 1. Create Account
# 2. Login
# 3. Exit
# Enter your choice (1/2/3): 1
# Enter your name: Jijil
# Account created successfully.
#
# Options:
# 1. Create Account
# 2. Login
# 3. Exit
# Enter your choice (1/2/3): 2
# Enter your name: jijil
# Account not found. Please create an account.
#
# Options:
# 1. Create Account
# 2. Login
# 3. Exit
# Enter your choice (1/2/3): 2
# Enter your name: Jijil
# Welcome back, Jijil!
#
# Account Options:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Logout
# Enter your choice (1/2/3/4): 3
# Jijil's account balance: 0
#
# Account Options:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Logout
# Enter your choice (1/2/3/4): 4
# Logged out successfully.
#
# Options:
# 1. Create Account
# 2. Login
# 3. Exit
# Enter your choice (1/2/3): 3
# Thank you for using Python Bank. Have a great day!

# %%
class BankAccount:
    def __init__(self, name, balance=0):
        self.name = name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount} into {self.name}'s account.")
            self.show_balance()
        else:
            print("Invalid deposit amount.")

    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew {amount} from {self.name}'s account.")
            self.show_balance()
        else:
            print("Insufficient funds or invalid withdrawal amount.")

    def show_balance(self):
        print(f"{self.name}'s account balance: {self.balance}")


class Bank:
    def __init__(self):
        self.accounts = {}

    def create_account(self, name, password):
        if name in self.accounts:
            print("Account already exists.")
        else:
            self.accounts[name] = {'password': password, 'account': BankAccount(name)}
            print("Account created successfully.")

    def login(self, name, password):
        if name in self.accounts and self.accounts[name]['password'] == password:
            print(f"Welcome back, {name}!")
            return self.accounts[name]['account']
        else:
            print("Invalid username or password.")
            return None


def main():
    print("Welcome to the Python Bank!")
    bank = Bank()

    while True:
        print("\nOptions:")
        print("1. Create Account")
        print("2. Login")
        print("3. Exit")

        choice = input("Enter your choice (1/2/3): ")

        if choice == '1':
            name = input("Enter your name: ")
            password = input("Enter your password: ")
            bank.create_account(name, password)
        elif choice == '2':
            name = input("Enter your name: ")
            password = input("Enter your password: ")
            account = bank.login(name, password)
            if account:
                account_menu(account)
        elif choice == '3':
            print("Thank you for using Python Bank. Have a great day!")
            break
        else:
            print("Invalid choice. Please choose again.")


def account_menu(account):
    while True:
        print("\nAccount Options:")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Logout")

        choice = input("Enter your choice (1/2/3/4): ")

        if choice == '1':
            amount = float(input("Enter amount to deposit: "))
            account.deposit(amount)
        elif choice == '2':
            amount = float(input("Enter amount to withdraw: "))
            account.withdraw(amount)
        elif choice == '3':
            account.show_balance()
        elif choice == '4':
            print("Logged out successfully.")
            break
        else:
            print("Invalid choice. Please choose again.")


if __name__ == "__main__":
    main()
# Out:
# Welcome to the Python Bank!
#
# Options:
# 1. Create Account
# 2. Login
# 3. Exit
# Enter your choice (1/2/3): 1
# Enter your name: jijil
# Enter your password: password
# Account created successfully.
#
# Options:
# 1. Create Account
# 2. Login
# 3. Exit
# Enter your choice (1/2/3): 2
# Enter your name: jijil
# Enter your password: password
# Welcome back, jijil!
#
# Account Options:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Logout
# Enter your choice (1/2/3/4): 4
# Logged out successfully.
#
# Options:
# 1. Create Account
# 2. Login
# 3. Exit
# Enter your choice (1/2/3): 3
# Thank you for using Python Bank. Have a great day!
